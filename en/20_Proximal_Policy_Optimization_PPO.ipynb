# %%
# !pip install stable-baselines3 imageio gymnasium matplotlib

import gymnasium as gym
from stable_baselines3 import PPO
import imageio

env = gym.make("Pendulum-v1", render_mode="rgb_array")

model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=300_000)

obs, _ = env.reset()
total_reward = 0
frames = []

for step in range(200):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, _ = env.step(action)
    total_reward += reward

    # Save frame for GIF
    img = env.render()
    frames.append(img)

    # Show logs
    print(f"Step {step}: Action={action}, Reward={reward:.2f}, Total Reward={total_reward:.2f}")

    if terminated or truncated:
        print("Episode finished, resetting environment")
        obs, _ = env.reset()
        total_reward = 0

env.close()

imageio.mimsave("pendulum.gif", frames, fps=30)
print("GIF saved as pendulum.gif")
# Out:
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.7.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (2.37.2)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.0.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.8.0+cu126)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.1.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio) (11.3.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# Downloading stable_baselines3-2.7.0-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.2/187.2 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: stable-baselines3
# Successfully installed stable-baselines3-2.7.0
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.19e+03 |
# | time/              |           |
# |    fps             | 1510      |
# |    iterations      | 1         |
# |    time_elapsed    | 1         |
# |    total_timesteps | 2048      |
# ----------------------------------
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.26e+03   |
# | time/                   |             |
# |    fps                  | 1202        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.002385456 |
# |    clip_fraction        | 0.0209      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | -0.00367    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.56e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00403    |
# |    std                  | 1.02        |
# |    value_loss           | 9.21e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 1050         |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0010833166 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.58e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00136     |
# |    std                  | 0.999        |
# |    value_loss           | 9.68e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.19e+03    |
# | time/                   |              |
# |    fps                  | 1043         |
# |    iterations           | 4            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0010288949 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.243        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.91e+03     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000539    |
# |    std                  | 0.99         |
# |    value_loss           | 6.75e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.2e+03     |
# | time/                   |              |
# |    fps                  | 1042         |
# |    iterations           | 5            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0012453629 |
# |    clip_fraction        | 0.000635     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0379       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.92e+03     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000791    |
# |    std                  | 0.993        |
# |    value_loss           | 7.3e+03      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -1.21e+03  |
# | time/                   |            |
# |    fps                  | 962        |
# |    iterations           | 6          |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00333118 |
# |    clip_fraction        | 0.022      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.41      |
# |    explained_variance   | 0.00771    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.43e+03   |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00269   |
# |    std                  | 0.995      |
# |    value_loss           | 9.53e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 950         |
# |    iterations           | 7           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.002653042 |
# |    clip_fraction        | 0.00693     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.00516     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.48e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000901   |
# |    std                  | 0.995       |
# |    value_loss           | 8.43e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 957          |
# |    iterations           | 8            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0040975227 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.00331      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.71e+03     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00259     |
# |    std                  | 0.979        |
# |    value_loss           | 8.11e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.2e+03     |
# | time/                   |              |
# |    fps                  | 965          |
# |    iterations           | 9            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0024120188 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.0022       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.69e+03     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00188     |
# |    std                  | 0.972        |
# |    value_loss           | 7.15e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.2e+03     |
# | time/                   |              |
# |    fps                  | 969          |
# |    iterations           | 10           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0025156562 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.00115      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.21e+03     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00144     |
# |    std                  | 0.98         |
# |    value_loss           | 5.75e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.18e+03    |
# | time/                   |              |
# |    fps                  | 972          |
# |    iterations           | 11           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0006754687 |
# |    clip_fraction        | 0.00381      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.000748     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.37e+03     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000606    |
# |    std                  | 0.992        |
# |    value_loss           | 6.47e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.16e+03    |
# | time/                   |              |
# |    fps                  | 928          |
# |    iterations           | 12           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0038537872 |
# |    clip_fraction        | 0.0321       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.000616     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.7e+03      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00274     |
# |    std                  | 0.98         |
# |    value_loss           | 5.97e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.16e+03    |
# | time/                   |              |
# |    fps                  | 936          |
# |    iterations           | 13           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0041172076 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.000454     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.23e+03     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00402     |
# |    std                  | 0.972        |
# |    value_loss           | 4.45e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.16e+03    |
# | time/                   |              |
# |    fps                  | 943          |
# |    iterations           | 14           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0021502492 |
# |    clip_fraction        | 0.00557      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.000288     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.9e+03      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000639    |
# |    std                  | 0.977        |
# |    value_loss           | 6.33e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 948          |
# |    iterations           | 15           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0023313724 |
# |    clip_fraction        | 0.00693      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000174     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.4e+03      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00155     |
# |    std                  | 0.954        |
# |    value_loss           | 6.03e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 952          |
# |    iterations           | 16           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0020487371 |
# |    clip_fraction        | 0.00684      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.000173     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.83e+03     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00124     |
# |    std                  | 0.938        |
# |    value_loss           | 5.13e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 953          |
# |    iterations           | 17           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0020303791 |
# |    clip_fraction        | 0.00742      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.000102     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.31e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00146     |
# |    std                  | 0.935        |
# |    value_loss           | 5.68e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.14e+03   |
# | time/                   |             |
# |    fps                  | 927         |
# |    iterations           | 18          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.001856501 |
# |    clip_fraction        | 0.00112     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 9.29e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.47e+03    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -4e-05      |
# |    std                  | 0.931       |
# |    value_loss           | 7.07e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.15e+03    |
# | time/                   |              |
# |    fps                  | 933          |
# |    iterations           | 19           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0033364007 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.000105     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.61e+03     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0032      |
# |    std                  | 0.919        |
# |    value_loss           | 5.63e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 937          |
# |    iterations           | 20           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0014792976 |
# |    clip_fraction        | 0.00195      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 8.45e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.72e+03     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000237    |
# |    std                  | 0.909        |
# |    value_loss           | 6.54e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.15e+03    |
# | time/                   |              |
# |    fps                  | 941          |
# |    iterations           | 21           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0040542325 |
# |    clip_fraction        | 0.0438       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.000106     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.46e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00374     |
# |    std                  | 0.899        |
# |    value_loss           | 3.81e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.15e+03    |
# | time/                   |              |
# |    fps                  | 944          |
# |    iterations           | 22           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0035058542 |
# |    clip_fraction        | 0.0143       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 8.38e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.49e+03     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00268     |
# |    std                  | 0.898        |
# |    value_loss           | 5.73e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.16e+03   |
# | time/                   |             |
# |    fps                  | 940         |
# |    iterations           | 23          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.002586463 |
# |    clip_fraction        | 0.013       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 6.23e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.93e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00139    |
# |    std                  | 0.878       |
# |    value_loss           | 3.8e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 925          |
# |    iterations           | 24           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0020821546 |
# |    clip_fraction        | 0.00776      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 4.16e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.16e+03     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00157     |
# |    std                  | 0.875        |
# |    value_loss           | 4.55e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 929          |
# |    iterations           | 25           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0024647396 |
# |    clip_fraction        | 0.00957      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 4.79e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.23e+03     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00151     |
# |    std                  | 0.876        |
# |    value_loss           | 3.17e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 930          |
# |    iterations           | 26           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0046800207 |
# |    clip_fraction        | 0.0464       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 3.28e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.78e+03     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00336     |
# |    std                  | 0.873        |
# |    value_loss           | 3.71e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 933          |
# |    iterations           | 27           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0037286154 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 2.21e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.79e+03     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00187     |
# |    std                  | 0.879        |
# |    value_loss           | 4.52e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.11e+03    |
# | time/                   |              |
# |    fps                  | 935          |
# |    iterations           | 28           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0035553726 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 1.56e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.05e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00331     |
# |    std                  | 0.869        |
# |    value_loss           | 4.39e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 926          |
# |    iterations           | 29           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0043290593 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 2.21e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.43e+03     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00139     |
# |    std                  | 0.849        |
# |    value_loss           | 3.37e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 922          |
# |    iterations           | 30           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0014655264 |
# |    clip_fraction        | 0.00356      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 1.56e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.33e+03     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000508    |
# |    std                  | 0.86         |
# |    value_loss           | 5.23e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.11e+03    |
# | time/                   |              |
# |    fps                  | 925          |
# |    iterations           | 31           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0031672032 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 1.75e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.86e+03     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00191     |
# |    std                  | 0.863        |
# |    value_loss           | 4.2e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 928          |
# |    iterations           | 32           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0038116532 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 1.76e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 979          |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00332     |
# |    std                  | 0.881        |
# |    value_loss           | 2.32e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 931          |
# |    iterations           | 33           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0022029672 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 1.22e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.62e+03     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00239     |
# |    std                  | 0.887        |
# |    value_loss           | 3.72e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 934          |
# |    iterations           | 34           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0024585375 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 1.03e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.96e+03     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00102     |
# |    std                  | 0.894        |
# |    value_loss           | 3.89e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 923          |
# |    iterations           | 35           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0030270796 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 1.21e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.09e+03     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0024      |
# |    std                  | 0.887        |
# |    value_loss           | 2.58e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.13e+03   |
# | time/                   |             |
# |    fps                  | 924         |
# |    iterations           | 36          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.003863251 |
# |    clip_fraction        | 0.0249      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 8.11e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.22e+03    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00226    |
# |    std                  | 0.89        |
# |    value_loss           | 2.91e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 927          |
# |    iterations           | 37           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0028424899 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 8.4e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13e+03     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00111     |
# |    std                  | 0.884        |
# |    value_loss           | 3.07e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 930          |
# |    iterations           | 38           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0021794436 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 9e-06        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.43e+03     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00192     |
# |    std                  | 0.88         |
# |    value_loss           | 2.66e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.11e+03    |
# | time/                   |              |
# |    fps                  | 932          |
# |    iterations           | 39           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0029848742 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 7.15e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31e+03     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00167     |
# |    std                  | 0.891        |
# |    value_loss           | 3.09e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.09e+03    |
# | time/                   |              |
# |    fps                  | 934          |
# |    iterations           | 40           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0050750785 |
# |    clip_fraction        | 0.046        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 7.21e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 905          |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00265     |
# |    std                  | 0.908        |
# |    value_loss           | 1.9e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.09e+03    |
# | time/                   |              |
# |    fps                  | 923          |
# |    iterations           | 41           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0026691696 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 6.14e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 952          |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000994    |
# |    std                  | 0.919        |
# |    value_loss           | 1.99e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.09e+03    |
# | time/                   |              |
# |    fps                  | 925          |
# |    iterations           | 42           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0027245716 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 4.53e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 655          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00278     |
# |    std                  | 0.914        |
# |    value_loss           | 1.56e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.08e+03    |
# | time/                   |              |
# |    fps                  | 928          |
# |    iterations           | 43           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0030766758 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 2.68e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.2e+03      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00205     |
# |    std                  | 0.899        |
# |    value_loss           | 2.79e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 929          |
# |    iterations           | 44           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0028716945 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 3.1e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 835          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00156     |
# ...
# |    value_loss           | 21.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -216       |
# | time/                   |            |
# |    fps                  | 927        |
# |    iterations           | 147        |
# |    time_elapsed         | 324        |
# |    total_timesteps      | 301056     |
# | train/                  |            |
# |    approx_kl            | 0.02006768 |
# |    clip_fraction        | 0.199      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.539     |
# |    explained_variance   | 0.987      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.03       |
# |    n_updates            | 1460       |
# |    policy_gradient_loss | 0.00175    |
# |    std                  | 0.411      |
# |    value_loss           | 3.76       |
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# Step 0: Action=[1.679568], Reward=-9.88, Total Reward=-9.88
# Step 1: Action=[2.], Reward=-9.64, Total Reward=-19.52
# Step 2: Action=[2.], Reward=-9.33, Total Reward=-28.85
# Step 3: Action=[2.], Reward=-8.97, Total Reward=-37.82
# Step 4: Action=[2.], Reward=-8.57, Total Reward=-46.39
# Step 5: Action=[2.], Reward=-8.13, Total Reward=-54.52
# Step 6: Action=[2.], Reward=-7.67, Total Reward=-62.19
# Step 7: Action=[2.], Reward=-7.21, Total Reward=-69.41
# Step 8: Action=[2.], Reward=-6.77, Total Reward=-76.17
# Step 9: Action=[2.], Reward=-6.35, Total Reward=-82.52
# Step 10: Action=[2.], Reward=-5.97, Total Reward=-88.49
# Step 11: Action=[2.], Reward=-5.65, Total Reward=-94.13
# Step 12: Action=[2.], Reward=-5.38, Total Reward=-99.52
# Step 13: Action=[2.], Reward=-5.19, Total Reward=-104.71
# Step 14: Action=[2.], Reward=-5.08, Total Reward=-109.79
# Step 15: Action=[2.], Reward=-5.04, Total Reward=-114.84
# Step 16: Action=[1.9072682], Reward=-5.09, Total Reward=-119.93
# Step 17: Action=[1.452643], Reward=-5.22, Total Reward=-125.14
# Step 18: Action=[0.8359226], Reward=-5.45, Total Reward=-130.60
# Step 19: Action=[0.093367], Reward=-5.84, Total Reward=-136.43
# Step 20: Action=[-0.6144272], Reward=-6.42, Total Reward=-142.85
# Step 21: Action=[-1.1000451], Reward=-7.23, Total Reward=-150.08
# Step 22: Action=[-1.3468747], Reward=-8.29, Total Reward=-158.37
# Step 23: Action=[-1.4520063], Reward=-9.56, Total Reward=-167.93
# Step 24: Action=[-1.4961157], Reward=-10.97, Total Reward=-178.90
# Step 25: Action=[-1.5261135], Reward=-10.59, Total Reward=-189.49
# Step 26: Action=[-1.5716796], Reward=-9.48, Total Reward=-198.97
# Step 27: Action=[-1.6494136], Reward=-8.35, Total Reward=-207.33
# Step 28: Action=[-1.7550157], Reward=-7.24, Total Reward=-214.57
# Step 29: Action=[-1.865233], Reward=-6.20, Total Reward=-220.77
# Step 30: Action=[-1.9631506], Reward=-5.25, Total Reward=-226.01
# Step 31: Action=[-2.], Reward=-4.42, Total Reward=-230.43
# Step 32: Action=[-2.], Reward=-3.71, Total Reward=-234.14
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Step 33: Action=[-2.], Reward=-3.14, Total Reward=-237.28
# Step 34: Action=[-2.], Reward=-2.70, Total Reward=-239.98
# Step 35: Action=[-2.], Reward=-2.37, Total Reward=-242.35
# Step 36: Action=[-2.], Reward=-2.16, Total Reward=-244.51
# Step 37: Action=[-2.], Reward=-2.05, Total Reward=-246.56
# Step 38: Action=[-2.], Reward=-2.05, Total Reward=-248.61
# Step 39: Action=[-2.], Reward=-2.15, Total Reward=-250.76
# Step 40: Action=[-1.7640839], Reward=-2.36, Total Reward=-253.12
# Step 41: Action=[-0.98508054], Reward=-2.70, Total Reward=-255.82
# Step 42: Action=[-0.23819746], Reward=-3.24, Total Reward=-259.06
# Step 43: Action=[0.2933684], Reward=-4.06, Total Reward=-263.12
# Step 44: Action=[0.59778696], Reward=-5.22, Total Reward=-268.34
# Step 45: Action=[0.77497387], Reward=-6.73, Total Reward=-275.07
# Step 46: Action=[0.9140811], Reward=-8.57, Total Reward=-283.64
# Step 47: Action=[1.07039], Reward=-10.69, Total Reward=-294.33
# Step 48: Action=[1.256432], Reward=-12.98, Total Reward=-307.31
# Step 49: Action=[1.426332], Reward=-12.56, Total Reward=-319.86
# Step 50: Action=[1.5136456], Reward=-10.86, Total Reward=-330.72
# Step 51: Action=[1.4922241], Reward=-9.13, Total Reward=-339.85
# Step 52: Action=[1.3791478], Reward=-7.45, Total Reward=-347.30
# Step 53: Action=[1.2120273], Reward=-5.91, Total Reward=-353.21
# Step 54: Action=[1.03578], Reward=-4.55, Total Reward=-357.76
# Step 55: Action=[0.8889077], Reward=-3.43, Total Reward=-361.19
# Step 56: Action=[0.7904176], Reward=-2.53, Total Reward=-363.72
# Step 57: Action=[0.74046886], Reward=-1.84, Total Reward=-365.56
# Step 58: Action=[0.73272336], Reward=-1.33, Total Reward=-366.90
# Step 59: Action=[0.7610486], Reward=-0.96, Total Reward=-367.86
# Step 60: Action=[0.81046885], Reward=-0.70, Total Reward=-368.55
# Step 61: Action=[0.85432106], Reward=-0.51, Total Reward=-369.06
# Step 62: Action=[0.8710479], Reward=-0.38, Total Reward=-369.44
# Step 63: Action=[0.85487294], Reward=-0.28, Total Reward=-369.72
# Step 64: Action=[0.8110512], Reward=-0.21, Total Reward=-369.93
# Step 65: Action=[0.7482637], Reward=-0.16, Total Reward=-370.09
# Step 66: Action=[0.67454153], Reward=-0.12, Total Reward=-370.22
# Step 67: Action=[0.5960463], Reward=-0.09, Total Reward=-370.31
# Step 68: Action=[0.51708955], Reward=-0.07, Total Reward=-370.38
# Step 69: Action=[0.44050902], Reward=-0.06, Total Reward=-370.44
# Step 70: Action=[0.3680693], Reward=-0.04, Total Reward=-370.48
# Step 71: Action=[0.3007815], Reward=-0.03, Total Reward=-370.51
# Step 72: Action=[0.239148], Reward=-0.02, Total Reward=-370.54
# Step 73: Action=[0.18332712], Reward=-0.02, Total Reward=-370.56
# Step 74: Action=[0.13325141], Reward=-0.01, Total Reward=-370.57
# Step 75: Action=[0.08870885], Reward=-0.01, Total Reward=-370.58
# Step 76: Action=[0.04939605], Reward=-0.01, Total Reward=-370.59
# Step 77: Action=[0.01495694], Reward=-0.01, Total Reward=-370.59
# Step 78: Action=[-0.0149923], Reward=-0.00, Total Reward=-370.60
# Step 79: Action=[-0.04084428], Reward=-0.00, Total Reward=-370.60
# Step 80: Action=[-0.06299007], Reward=-0.00, Total Reward=-370.60
# Step 81: Action=[-0.08180821], Reward=-0.00, Total Reward=-370.61
# Step 82: Action=[-0.09766012], Reward=-0.00, Total Reward=-370.61
# Step 83: Action=[-0.11088735], Reward=-0.00, Total Reward=-370.61
# Step 84: Action=[-0.12180781], Reward=-0.00, Total Reward=-370.61
# Step 85: Action=[-0.13071464], Reward=-0.00, Total Reward=-370.61
# Step 86: Action=[-0.13787688], Reward=-0.00, Total Reward=-370.61
# Step 87: Action=[-0.14353812], Reward=-0.00, Total Reward=-370.61
# Step 88: Action=[-0.14791802], Reward=-0.00, Total Reward=-370.61
# Step 89: Action=[-0.1512132], Reward=-0.00, Total Reward=-370.61
# Step 90: Action=[-0.1535985], Reward=-0.00, Total Reward=-370.61
# Step 91: Action=[-0.15522788], Reward=-0.00, Total Reward=-370.61
# Step 92: Action=[-0.15623608], Reward=-0.00, Total Reward=-370.61
# Step 93: Action=[-0.15674064], Reward=-0.00, Total Reward=-370.61
# Step 94: Action=[-0.15684257], Reward=-0.00, Total Reward=-370.62
# Step 95: Action=[-0.15662892], Reward=-0.00, Total Reward=-370.62
# Step 96: Action=[-0.15617332], Reward=-0.00, Total Reward=-370.62
# Step 97: Action=[-0.15553793], Reward=-0.00, Total Reward=-370.62
# Step 98: Action=[-0.15477473], Reward=-0.00, Total Reward=-370.62
# Step 99: Action=[-0.15392637], Reward=-0.00, Total Reward=-370.62
# Step 100: Action=[-0.15302797], Reward=-0.00, Total Reward=-370.62
# Step 101: Action=[-0.15210767], Reward=-0.00, Total Reward=-370.62
# Step 102: Action=[-0.15118778], Reward=-0.00, Total Reward=-370.62
# Step 103: Action=[-0.15028578], Reward=-0.00, Total Reward=-370.62
# Step 104: Action=[-0.14941484], Reward=-0.00, Total Reward=-370.62
# Step 105: Action=[-0.14858428], Reward=-0.00, Total Reward=-370.62
# Step 106: Action=[-0.14780104], Reward=-0.00, Total Reward=-370.63
# Step 107: Action=[-0.14706922], Reward=-0.00, Total Reward=-370.63
# Step 108: Action=[-0.14639157], Reward=-0.00, Total Reward=-370.63
# Step 109: Action=[-0.14576842], Reward=-0.00, Total Reward=-370.63
# Step 110: Action=[-0.14519963], Reward=-0.00, Total Reward=-370.63
# Step 111: Action=[-0.1446836], Reward=-0.00, Total Reward=-370.63
# Step 112: Action=[-0.14421833], Reward=-0.00, Total Reward=-370.63
# Step 113: Action=[-0.14380142], Reward=-0.00, Total Reward=-370.63
# Step 114: Action=[-0.1434296], Reward=-0.00, Total Reward=-370.63
# Step 115: Action=[-0.14309998], Reward=-0.00, Total Reward=-370.63
# Step 116: Action=[-0.14280957], Reward=-0.00, Total Reward=-370.63
# Step 117: Action=[-0.14255446], Reward=-0.00, Total Reward=-370.64
# Step 118: Action=[-0.14233208], Reward=-0.00, Total Reward=-370.64
# Step 119: Action=[-0.14213923], Reward=-0.00, Total Reward=-370.64
# Step 120: Action=[-0.14197248], Reward=-0.00, Total Reward=-370.64
# Step 121: Action=[-0.14182952], Reward=-0.00, Total Reward=-370.64
# Step 122: Action=[-0.14170757], Reward=-0.00, Total Reward=-370.64
# Step 123: Action=[-0.14160427], Reward=-0.00, Total Reward=-370.64
# Step 124: Action=[-0.1415174], Reward=-0.00, Total Reward=-370.64
# Step 125: Action=[-0.1414448], Reward=-0.00, Total Reward=-370.64
# Step 126: Action=[-0.14138454], Reward=-0.00, Total Reward=-370.64
# Step 127: Action=[-0.14133538], Reward=-0.00, Total Reward=-370.64
# Step 128: Action=[-0.1412953], Reward=-0.00, Total Reward=-370.64
# Step 129: Action=[-0.14126326], Reward=-0.00, Total Reward=-370.65
# Step 130: Action=[-0.1412378], Reward=-0.00, Total Reward=-370.65
# Step 131: Action=[-0.14121845], Reward=-0.00, Total Reward=-370.65
# Step 132: Action=[-0.14120358], Reward=-0.00, Total Reward=-370.65
# Step 133: Action=[-0.14119281], Reward=-0.00, Total Reward=-370.65
# Step 134: Action=[-0.14118537], Reward=-0.00, Total Reward=-370.65
# Step 135: Action=[-0.14118049], Reward=-0.00, Total Reward=-370.65
# Step 136: Action=[-0.14117786], Reward=-0.00, Total Reward=-370.65
# Step 137: Action=[-0.14117718], Reward=-0.00, Total Reward=-370.65
# Step 138: Action=[-0.14117756], Reward=-0.00, Total Reward=-370.65
# Step 139: Action=[-0.14117908], Reward=-0.00, Total Reward=-370.65
# Step 140: Action=[-0.14118145], Reward=-0.00, Total Reward=-370.65
# Step 141: Action=[-0.14118434], Reward=-0.00, Total Reward=-370.66
# Step 142: Action=[-0.1411875], Reward=-0.00, Total Reward=-370.66
# Step 143: Action=[-0.14119107], Reward=-0.00, Total Reward=-370.66
# Step 144: Action=[-0.1411946], Reward=-0.00, Total Reward=-370.66
# Step 145: Action=[-0.14119834], Reward=-0.00, Total Reward=-370.66
# Step 146: Action=[-0.14120196], Reward=-0.00, Total Reward=-370.66
# Step 147: Action=[-0.14120534], Reward=-0.00, Total Reward=-370.66
# Step 148: Action=[-0.14120856], Reward=-0.00, Total Reward=-370.66
# Step 149: Action=[-0.1412119], Reward=-0.00, Total Reward=-370.66
# Step 150: Action=[-0.14121464], Reward=-0.00, Total Reward=-370.66
# Step 151: Action=[-0.14121744], Reward=-0.00, Total Reward=-370.66
# Step 152: Action=[-0.1412198], Reward=-0.00, Total Reward=-370.66
# Step 153: Action=[-0.14122221], Reward=-0.00, Total Reward=-370.66
# Step 154: Action=[-0.14122424], Reward=-0.00, Total Reward=-370.67
# Step 155: Action=[-0.14122589], Reward=-0.00, Total Reward=-370.67
# Step 156: Action=[-0.14122754], Reward=-0.00, Total Reward=-370.67
# Step 157: Action=[-0.14122918], Reward=-0.00, Total Reward=-370.67
# Step 158: Action=[-0.1412304], Reward=-0.00, Total Reward=-370.67
# Step 159: Action=[-0.14123158], Reward=-0.00, Total Reward=-370.67
# Step 160: Action=[-0.14123279], Reward=-0.00, Total Reward=-370.67
# Step 161: Action=[-0.14123361], Reward=-0.00, Total Reward=-370.67
# Step 162: Action=[-0.14123437], Reward=-0.00, Total Reward=-370.67
# Step 163: Action=[-0.1412352], Reward=-0.00, Total Reward=-370.67
# Step 164: Action=[-0.14123559], Reward=-0.00, Total Reward=-370.67
# Step 165: Action=[-0.14123619], Reward=-0.00, Total Reward=-370.67
# Step 166: Action=[-0.1412365], Reward=-0.00, Total Reward=-370.68
# Step 167: Action=[-0.14123681], Reward=-0.00, Total Reward=-370.68
# Step 168: Action=[-0.14123726], Reward=-0.00, Total Reward=-370.68
# Step 169: Action=[-0.14123751], Reward=-0.00, Total Reward=-370.68
# Step 170: Action=[-0.14123772], Reward=-0.00, Total Reward=-370.68
# Step 171: Action=[-0.14123784], Reward=-0.00, Total Reward=-370.68
# Step 172: Action=[-0.14123787], Reward=-0.00, Total Reward=-370.68
# Step 173: Action=[-0.14123803], Reward=-0.00, Total Reward=-370.68
# Step 174: Action=[-0.14123803], Reward=-0.00, Total Reward=-370.68
# Step 175: Action=[-0.14123823], Reward=-0.00, Total Reward=-370.68
# Step 176: Action=[-0.14123818], Reward=-0.00, Total Reward=-370.68
# Step 177: Action=[-0.14123833], Reward=-0.00, Total Reward=-370.68
# Step 178: Action=[-0.14123835], Reward=-0.00, Total Reward=-370.69
# Step 179: Action=[-0.14123836], Reward=-0.00, Total Reward=-370.69
# Step 180: Action=[-0.14123845], Reward=-0.00, Total Reward=-370.69
# Step 181: Action=[-0.1412382], Reward=-0.00, Total Reward=-370.69
# Step 182: Action=[-0.1412382], Reward=-0.00, Total Reward=-370.69
# Step 183: Action=[-0.14123829], Reward=-0.00, Total Reward=-370.69
# Step 184: Action=[-0.1412383], Reward=-0.00, Total Reward=-370.69
# Step 185: Action=[-0.14123836], Reward=-0.00, Total Reward=-370.69
# Step 186: Action=[-0.14123845], Reward=-0.00, Total Reward=-370.69
# Step 187: Action=[-0.14123836], Reward=-0.00, Total Reward=-370.69
# Step 188: Action=[-0.14123836], Reward=-0.00, Total Reward=-370.69
# Step 189: Action=[-0.14123835], Reward=-0.00, Total Reward=-370.69
# Step 190: Action=[-0.14123845], Reward=-0.00, Total Reward=-370.70
# Step 191: Action=[-0.14123842], Reward=-0.00, Total Reward=-370.70
# Step 192: Action=[-0.14123848], Reward=-0.00, Total Reward=-370.70
# Step 193: Action=[-0.14123851], Reward=-0.00, Total Reward=-370.70
# Step 194: Action=[-0.1412384], Reward=-0.00, Total Reward=-370.70
# Step 195: Action=[-0.14123847], Reward=-0.00, Total Reward=-370.70
# Step 196: Action=[-0.14123839], Reward=-0.00, Total Reward=-370.70
# Step 197: Action=[-0.14123836], Reward=-0.00, Total Reward=-370.70
# Step 198: Action=[-0.14123821], Reward=-0.00, Total Reward=-370.70
# Step 199: Action=[-0.14123815], Reward=-0.00, Total Reward=-370.70
# Episode finished, resetting environment
# /usr/local/lib/python3.12/dist-packages/imageio/plugins/pillow.py:410: DeprecationWarning: The keyword `fps` is no longer supported. Use `duration`(in ms) instead, e.g. `fps=50` == `duration=20` (1000 * 1/50).
#   warnings.warn(
# GIF saved as pendulum.gif
