# %%
# !pip install keras_tuner
import time
import datetime
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.initializers import HeNormal
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
import keras_tuner as kt

def get_timestamp():
    return datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

def build_model(hp):
    model = Sequential()
    neurons_l1 = hp.Int('neurons_l1', min_value=4, max_value=6, step=1)
    neurons_l2 = hp.Int('neurons_l2', min_value=4, max_value=6, step=1)
    dropout_rate = hp.Float('dropout_rate', min_value=0.1, max_value=0.3, step=0.1)
    l2_lambda = hp.Choice('l2_lambda', values=[0.01, 0.001])
    learning_rate = hp.Choice('learning_rate', values=[0.01, 0.001])
    model.add(Dense(neurons_l1, input_dim=4, activation='relu', kernel_initializer=HeNormal(), kernel_regularizer=l2(l2_lambda)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neurons_l2, activation='relu', kernel_initializer=HeNormal(), kernel_regularizer=l2(l2_lambda)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(3, activation='softmax'))
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def save_plot(history, filename):
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.savefig(filename)

def log_results(filename, tuning_time, training_time, execution_time, history, test_loss, test_accuracy, image_filename, best_hyperparameters):
    with open(filename, 'w') as f:
        f.write(f"Tuning Time: {tuning_time:.4f} seconds\n")
        f.write(f"Training Time: {training_time:.4f} seconds\n")
        f.write(f"Execution Time: {execution_time:.4f} seconds\n")
        f.write(f"Test Loss: {test_loss:.4f}\n")
        f.write(f"Test Accuracy: {test_accuracy:.4f}\n")
        f.write(f"Image Filename: {image_filename}\n")
        f.write(f"Best Hyperparameters: {best_hyperparameters}\n")

def log_trial_results(trial_hyperparameters, val_accuracy, val_loss):
    with open("trial_results.txt", 'a') as f:
        f.write(f"Hyperparameters: {trial_hyperparameters}\n")
        f.write(f"Validation Accuracy: {val_accuracy:.4f}, Validation Loss: {val_loss:.4f}\n")
        f.write("-"*50 + "\n")

iris = load_iris()
X = StandardScaler().fit_transform(iris.data)
Y = to_categorical(iris.target)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

start_tuning = time.time()
tuner = kt.GridSearch(
    build_model,
    objective='val_accuracy',
    max_trials=200,
    executions_per_trial=1,
    directory='keras_tuner_dir',
    project_name='iris_grid_search'
)
tuner.search(X_train, Y_train, epochs=150, validation_split=0.2, verbose=1,
             callbacks=[TensorBoard(log_dir='logs')])
tuning_time = time.time() - start_tuning

# Save results of each trial
for trial in tuner.oracle.trials.values():
    log_trial_results(trial.hyperparameters.values, trial.metrics.get_best_value("val_accuracy"), trial.metrics.get_best_value("val_loss"))

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
best_model = tuner.hypermodel.build(best_hps)

start_training = time.time()
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = best_model.fit(X_train, Y_train, batch_size=32, epochs=200, validation_split=0.2, callbacks=[early_stop], verbose=1)
training_time = time.time() - start_training

start_execution = time.time()
test_loss, test_accuracy = best_model.evaluate(X_test, Y_test, verbose=0)
execution_time = time.time() - start_execution

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

timestamp = get_timestamp()
image_filename = f"{timestamp}.png"
log_filename = f"{timestamp}.txt"
save_plot(history, image_filename)
log_results(log_filename, tuning_time, training_time, execution_time, history, test_loss, test_accuracy, image_filename, best_hps.values)
# Out:
# Trial 72 Complete [00h 00m 19s]
# val_accuracy: 0.9583333134651184
#
# Best val_accuracy So Far: 1.0
# Total elapsed time: 00h 22m 27s
# Epoch 1/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.3359 - loss: 1.2212 - val_accuracy: 0.6250 - val_loss: 1.0121
# Epoch 2/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.3854 - loss: 1.1750 - val_accuracy: 0.5833 - val_loss: 0.9859
# Epoch 3/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.
# Epoch 83/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8490 - loss: 0.3833 - val_accuracy: 1.0000 - val_loss: 0.1912
# Epoch 84/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9297 - loss: 0.3236 - val_accuracy: 1.0000 - val_loss: 0.1843
# Epoch 85/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9297 - loss: 0.2984 - val_accuracy: 1.0000 - val_loss: 0.1857
# Epoch 86/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9336 - loss: 0.2463 - val_accuracy: 1.0000 - val_loss: 0.1960
# Epoch 87/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9323 - loss: 0.2855 - val_accuracy: 0.9583 - val_loss: 0.2019
# Epoch 88/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9167 - loss: 0.2821 - val_accuracy: 0.9583 - val_loss: 0.1953
# Epoch 89/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9427 - loss: 0.2822 - val_accuracy: 1.0000 - val_loss: 0.1859
# Epoch 90/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9049 - loss: 0.3377 - val_accuracy: 1.0000 - val_loss: 0.1815
# Epoch 91/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9180 - loss: 0.3146 - val_accuracy: 1.0000 - val_loss: 0.1826
# Epoch 92/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9661 - loss: 0.2419 - val_accuracy: 1.0000 - val_loss: 0.1825
# Epoch 93/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9505 - loss: 0.2943 - val_accuracy: 1.0000 - val_loss: 0.1803
# Epoch 94/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9544 - loss: 0.2475 - val_accuracy: 1.0000 - val_loss: 0.1834
# Epoch 95/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9193 - loss: 0.3252 - val_accuracy: 1.0000 - val_loss: 0.1769
# Epoch 96/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9049 - loss: 0.3195 - val_accuracy: 1.0000 - val_loss: 0.1792
# Epoch 97/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8906 - loss: 0.3396 - val_accuracy: 1.0000 - val_loss: 0.1839
# Epoch 98/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9401 - loss: 0.2690 - val_accuracy: 1.0000 - val_loss: 0.1894
# Epoch 99/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9115 - loss: 0.3310 - val_accuracy: 1.0000 - val_loss: 0.1858
# Epoch 100/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9245 - loss: 0.3281 - val_accuracy: 1.0000 - val_loss: 0.1748
# Epoch 101/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9206 - loss: 0.3178 - val_accuracy: 1.0000 - val_loss: 0.1702
# Epoch 102/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9583 - loss: 0.2323 - val_accuracy: 1.0000 - val_loss: 0.1714
# Epoch 103/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9128 - loss: 0.3188 - val_accuracy: 1.0000 - val_loss: 0.1772
# Epoch 104/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9648 - loss: 0.2566 - val_accuracy: 1.0000 - val_loss: 0.1873
# Epoch 105/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9167 - loss: 0.3432 - val_accuracy: 0.9583 - val_loss: 0.1949
# Epoch 106/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9141 - loss: 0.2954 - val_accuracy: 0.9583 - val_loss: 0.1924
# Epoch 107/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9453 - loss: 0.2585 - val_accuracy: 1.0000 - val_loss: 0.1830
# Epoch 108/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9453 - loss: 0.2632 - val_accuracy: 1.0000 - val_loss: 0.1882
# Epoch 109/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9232 - loss: 0.2980 - val_accuracy: 0.9583 - val_loss: 0.1910
# Epoch 110/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9570 - loss: 0.2653 - val_accuracy: 1.0000 - val_loss: 0.1812
# Epoch 111/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9154 - loss: 0.2949 - val_accuracy: 1.0000 - val_loss: 0.1702
# Epoch 112/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9505 - loss: 0.2501 - val_accuracy: 1.0000 - val_loss: 0.1649
# Epoch 113/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9466 - loss: 0.2692 - val_accuracy: 1.0000 - val_loss: 0.1663
# Epoch 114/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9323 - loss: 0.2746 - val_accuracy: 1.0000 - val_loss: 0.1678
# Epoch 115/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9492 - loss: 0.2920 - val_accuracy: 1.0000 - val_loss: 0.1686
# Epoch 116/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9492 - loss: 0.2744 - val_accuracy: 1.0000 - val_loss: 0.1662
# Epoch 117/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9219 - loss: 0.2747 - val_accuracy: 0.9583 - val_loss: 0.1741
# Epoch 118/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9115 - loss: 0.3216 - val_accuracy: 1.0000 - val_loss: 0.1715
# Epoch 119/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9648 - loss: 0.2987 - val_accuracy: 1.0000 - val_loss: 0.1717
# Epoch 120/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9232 - loss: 0.3266 - val_accuracy: 1.0000 - val_loss: 0.1692
# Epoch 121/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9310 - loss: 0.3162 - val_accuracy: 1.0000 - val_loss: 0.1671
# Epoch 122/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9505 - loss: 0.2390 - val_accuracy: 1.0000 - val_loss: 0.1741
# Test Loss: 0.1692
# Test Accuracy: 0.9667
